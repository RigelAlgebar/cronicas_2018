# %%
a = randn((2,2))
b = randn((2,2))

println(dot(a,b))
println(a,b)
println(a*b)
println(eig(a))
# Out:
# 0.08992566616384315
# [-0.145845 -0.113761; -1.30767 -0.153023][1.43171 -0.44296; -0.0506767 -1.18984]
# [-0.203042 0.199962; -1.86445 0.761319]
# ([0.23628, -0.535147], [0.285331 0.280488; -0.958429 0.959858])

# %%
x = 0
y = 1


println(~x)
println(x & y)
println(x | y)
println(x ⊻ y)
println(x >>> y)
println(x >> y)
println(x << y)
# Out:
# -1
# 0
# 1
# 1
# 0
# 0
# 0

# %%
if x < y
  print(x)
  print(" es menor que ")
  println(y)
elseif x > y
  print(x)
  print(" es mayor que ")
  println(y)
else
  print(x)
  print(" es igual que ")
  println(y)
end
# Out:
# 0 es menor que 1

# %%
function test(x, y)
    if x < y
        print(x)
        print(" es menor que ")
        println(y)
    elseif x > y
        print(x)
        print(" es mayor que ")
        println(y)
    else
        print(x)
        print(" es igual que ")
        println(y)
    end
end
# Out:
# test (generic function with 1 method)

# %%
test(1,2)
test(2,1)
test(2,2)
# Out:
# 1 es menor que 2
# 2 es mayor que 1
# 2 es igual que 2

# %%
using PyPlot

n = 100
u = linspace(0,2*π,n);
v = linspace(0,π,n);

x = cos.(u) * sin.(v)';
y = sin.(u) * sin.(v)';
z = ones(n) * cos.(v)';

# The rstride and cstride arguments default to 10
surf(x,y,z, rstride=4, cstride=4, alpha=0.5)

e_x = linspace(0,1.1,n)
e_y = linspace(-1.1,0,n)
e_z = linspace(0,1.1,n)
e_c = zeros(n)

plot(e_x,e_c,e_c, color="yellow", linewidth=3 )
plot(e_c,e_y,e_c, color="yellow", linewidth=3 )
plot(e_c,e_c,e_z, color="yellow", linewidth=3 )


plot( diag(x), diag(y), diag(z), color="yellow", linewidth=3 )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ffaeef1a410>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <mpl_toolkits.mplot3d.art3d.Line3D object at 0x7ffae9e93c90>
